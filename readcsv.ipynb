# %% [markdown]
# # GEOS 505, Assignment 1
#
# ## Background
# As part of a research project funded by the Idaho Transportation Department, I am currently assessing the impact that Reclaimed Asphalt Pavement (RAP) has on pavement performance. Specifically, the potential increase in crack suscebtibility with increasing RAP content. As part of that effort, I am conducting a newly developed test called the Illinois Flexibility Index Test (IFIT) which has been shown to be sensitive to RAP content. The dataset I have imported is the load displacement data from one of these tests.
#
# ## Workflow
# I begin by importing the libraries I may need to complete this task

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Next, I created a path to the file I want to open.

# %%
folder= os.getcwd()
file_name = '13463-1-A-1raw.csv'
path = folder+'\\'+file_name

# %% [markdown]
# Note: This file needed no cleanup and I don't really know any other ways to import the data at this point?
# Next, I created the dataframe and plotted the data.

# %%
df = pd.read_csv(path)
headers = df.columns.values
D = headers[3]
L = headers[2]
plt.plot(df[T].values,df[L].values)
plt.title('IFIT Semi-Circular Bend Test', fontsize=10)
plt.suptitle('Impact of RAP on Asphalt Durability', fontsize=14)
plt.xlabel('Displacement (mm)')
plt.ylabel('Load (kN)')
# Out:
# Text(0,0.5,'Load (kN)')
